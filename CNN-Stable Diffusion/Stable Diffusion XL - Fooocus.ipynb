# %% [markdown]
# Paper: https://arxiv.org/abs/2307.01952
#
# Github: https://github.com/lllyasviel/Fooocus

# %%
# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 16.8 MB/s eta 0:00:00
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 4917, done.
# remote: Counting objects: 100% (1201/1201), done.
# remote: Compressing objects: 100% (119/119), done.
# remote: Total 4917 (delta 1122), reused 1087 (delta 1081), pack-reused 3716
# Receiving objects: 100% (4917/4917), 24.86 MiB | 25.10 MiB/s, done.
# Resolving deltas: 100% (3025/3025), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share']
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Fooocus version: 2.1.860
# Installing requirements
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/juggernautXL_version6Rundiffusion.safetensors" to /content/Fooocus/models/checkpoints/juggernautXL_version6Rundiffusion.safetensors
#
# 100% 6.62G/6.62G [00:35<00:00, 198MB/s]
# ...

# %% [markdown]
# #### Extra
#
# Clipdrop by StabilityAI: https://clipdrop.co/
#
# Stable Audio by StabilityAI: https://www.stableaudio.com/
